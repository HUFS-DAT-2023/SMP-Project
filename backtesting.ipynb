# %% [markdown]
# ### Keras & TensorFlow to Predict Market Movements and Backtesting

# %%
# make the necessary imports 
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
import datetime
import pyfolio as pf
import backtrader as bt
from backtrader.feeds import PandasData
import warnings
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.layers import LSTM, Dropout, Dense, Activation
from keras.models import Sequential
from talib import RSI, BBANDS, MACD

# set the style and ignore warnings
plt.style.use('seaborn-colorblind')
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')
# Out:
# /Users/ihobbang/miniforge3/envs/main/lib/python3.8/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(
# /var/folders/82/yjz_v88n7jnb6641bk83qtvw0000gn/T/ipykernel_14811/2636440971.py:19: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-colorblind')

# %%
# this is to display images in notebook
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### 데이터 수집

# %%
# download ticker stock price from yahoo finance
stock = pd.read_csv('./Data/kodex200_data.csv')
stock['날짜'] = pd.to_datetime(stock['날짜'])
stock.set_index('날짜', inplace=True)
stock.rename(columns = {'종가':'close'}, inplace=True)
stock = stock.loc[:, ['close']]
stock.head(2)
# Out:
#             close
# 날짜
# 2013-01-04  26870
# 2013-01-07  26885

# %%
# calculate daily log returns and market direction
stock['returns'] = np.log(stock['close'] / stock['close'].shift(1))
stock.dropna(inplace=True)
stock['direction'] = np.sign(stock['returns']).astype(int)
stock.head(3)
# Out:
#             close   returns  direction
# 날짜
# 2013-01-07  26885  0.000558          1
# 2013-01-08  26600 -0.010657         -1
# 2013-01-09  26500 -0.003766         -1

# %%
# visualize the closing price and daily returns
ticker = 'KODEX200'
fig, ax = plt.subplots(2, 1, sharex=True, figsize = (12,6))
ax[0].plot(stock['close'], label = f'{ticker} Adj Close')
ax[0].set(title = f'{ticker} Closing Price', ylabel = 'Price')
ax[0].grid(True)
ax[0].legend()

ax[1].plot(stock['returns'], label = 'Daily Returns')
ax[1].set(title = f'{ticker} Daily Returns', ylabel = 'Returns')
ax[1].legend()
ax[1].grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
# define the number of lags
lags = [1, 2, 3, 4, 5]

# %%
# compute lagged log returns
cols = []
for lag in lags:
    col = f'rtn_lag{lag}'
    stock[col] = stock['returns'].shift(lag)
    cols.append(col)
stock.head(2)
# Out:
#             close   returns  direction  rtn_lag1  rtn_lag2  rtn_lag3  \
# 날짜
# 2013-01-07  26885  0.000558          1       NaN       NaN       NaN
# 2013-01-08  26600 -0.010657         -1  0.000558       NaN       NaN
#
#             rtn_lag4  rtn_lag5
# 날짜
# 2013-01-07       NaN       NaN
# 2013-01-08       NaN       NaN

# %%
# RSI - Relative Strenght Index
stock['rsi'] = RSI(stock.close)

# append to feature columns list
cols.append('rsi')
stock.tail(2)
# Out:
#             close   returns  direction  rtn_lag1  rtn_lag2  rtn_lag3  \
# 날짜
# 2023-01-03  29420  0.000000          0 -0.005931 -0.018082 -0.011875
# 2023-01-04  30040  0.020855          1  0.000000 -0.005931 -0.018082
#
#             rtn_lag4  rtn_lag5        rsi
# 날짜
# 2023-01-03  0.007075  0.001487  33.147497
# 2023-01-04 -0.011875  0.007075  43.618207

# %%
# Compute Bollinger Bands
high, mid, low = BBANDS(stock.close, timeperiod=20)
stock = stock.join(pd.DataFrame({'bb_high': high, 'bb_low': low}, index=stock.index))

# append to feature columns list
cols.append('bb_high')
cols.append('bb_low')

# %%
# Compute Moving Average Convergence/ Divergence
stock['macd'] = MACD(stock.close)[0]

# append to feature columns list
cols.append('macd')

# %%
# # let's look at the head and tail of our dataframe
stock.tail()
# Out:
#             close   returns  direction  rtn_lag1  rtn_lag2  rtn_lag3  \
# 날짜
# 2022-12-28  30135 -0.011875         -1  0.007075  0.001487 -0.017377
# 2022-12-29  29595 -0.018082         -1 -0.011875  0.007075  0.001487
# 2023-01-02  29420 -0.005931         -1 -0.018082 -0.011875  0.007075
# 2023-01-03  29420  0.000000          0 -0.005931 -0.018082 -0.011875
# 2023-01-04  30040  0.020855          1  0.000000 -0.005931 -0.018082
#
#             rtn_lag4  rtn_lag5        rsi       bb_high        bb_low  \
# 날짜
# 2022-12-28  0.012922 -0.002466  40.164281  31892.780539  29870.719461
# 2022-12-29 -0.017377  0.012922  34.716600  31696.597378  29799.902622
# 2023-01-02  0.001487 -0.017377  33.147497  31681.275709  29602.724291
# 2023-01-03  0.007075  0.001487  33.147497  31640.196565  29441.303435
# 2023-01-04 -0.011875  0.007075  43.618207  31585.022270  29395.977730
#
#                   macd
# 날짜
# 2022-12-28 -230.293040
# 2022-12-29 -291.477748
# 2023-01-02 -350.052916
# 2023-01-03 -391.955934
# 2023-01-04 -370.860510

# %% [markdown]
# ### Build and Apply the Model

# %%
# split the dataset in training and test datasets
train, test = train_test_split(stock.dropna(), test_size=0.05, shuffle=False)

# sort the data on date index
train = train.copy().sort_index()
test = test.copy().sort_index()

# %%
# # view train dataset
train.head()
# Out:
#             close   returns  direction  rtn_lag1  rtn_lag2  rtn_lag3  \
# 날짜
# 2013-02-22  26995  0.001483          1 -0.004627  0.021273  0.002833
# 2013-02-25  26890 -0.003897         -1  0.001483 -0.004627  0.021273
# 2013-02-26  26770 -0.004473         -1 -0.003897  0.001483 -0.004627
# 2013-02-27  26795  0.000933          1 -0.004473 -0.003897  0.001483
# 2013-02-28  27060  0.009841          1  0.000933 -0.004473 -0.003897
#
#             rtn_lag4  rtn_lag5        rsi       bb_high        bb_low  \
# 날짜
# 2013-02-22 -0.000378 -0.002078  63.160766  27067.348277  25312.651723
# 2013-02-25  0.002833 -0.000378  59.987825  27152.794465  25336.705535
# 2013-02-26  0.021273  0.002833  56.494815  27201.838237  25389.161763
# 2013-02-27 -0.004627  0.021273  57.055843  27255.238809  25417.761191
# 2013-02-28  0.001483 -0.004627  62.566398  27347.917442  25422.082558
#
#                   macd
# 날짜
# 2013-02-22   88.592440
# 2013-02-25  111.358937
# 2013-02-26  118.354238
# 2013-02-27  124.480423
# 2013-02-28  149.001162

# %%
# view test dataset
test.head()
# Out:
#             close   returns  direction  rtn_lag1  rtn_lag2  rtn_lag3  \
# 날짜
# 2022-07-11  30955 -0.005637         -1  0.005476  0.019900 -0.022963
# 2022-07-12  30660 -0.009576         -1 -0.005637  0.005476  0.019900
# 2022-07-13  30820  0.005205          1 -0.009576 -0.005637  0.005476
# 2022-07-14  30710 -0.003575         -1  0.005205 -0.009576 -0.005637
# 2022-07-15  30895  0.006006          1 -0.003575  0.005205 -0.009576
#
#             rtn_lag4  rtn_lag5        rsi       bb_high        bb_low  \
# 날짜
# 2022-07-11  0.015741  0.000327  39.463601  32664.631110  30027.868890
# 2022-07-12 -0.022963  0.015741  37.218997  32384.276338  30087.223662
# 2022-07-13  0.019900 -0.022963  39.237643  32217.030701  30107.969299
# 2022-07-14  0.005476  0.019900  38.325266  32025.868882  30143.631118
# 2022-07-15 -0.005637  0.005476  40.817719  31866.893399  30189.606601
#
#                   macd
# 날짜
# 2022-07-11 -792.685541
# 2022-07-12 -772.142835
# 2022-07-13 -734.485241
# 2022-07-14 -705.386155
# 2022-07-15 -659.791302

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
train["close_scaled"]=mms.fit_transform(train[["close"]])
test["close_scaled"]=mms.fit_transform(test[["close"]])
train_set = train.loc[:,["close_scaled", "returns", "direction"]]
test_set = test.loc[:,["close_scaled", "returns", "direction"]]

# %%
# map market direction of (1,-1) to (1,0)
train_set['direction_'] = np.where(train_set['direction'] > 0, 1, 0)
test_set['direction_'] = np.where(test_set['direction'] > 0, 1, 0)

# %%
test_set.head()
# Out:
#             close_scaled   returns  direction  direction_
# 날짜
# 2022-07-11      0.543060 -0.005637         -1           0
# 2022-07-12      0.483283 -0.009576         -1           0
# 2022-07-13      0.515704  0.005205          1           1
# 2022-07-14      0.493414 -0.003575         -1           0
# 2022-07-15      0.530902  0.006006          1           1

# %%
input_window = 3
data=list()
for i in range(len(train_set)-input_window):
    data.append(list(train_set["close_scaled"][i: i + input_window].values))

x_train = np.array(data)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = train_set["direction_"][input_window:]
print(x_train.shape, y_train.shape)
# Out:
# (2303, 3, 1) (2303,)

# %%
data=list()
for i in range(len(test_set)-input_window):
    data.append(list(test_set["close_scaled"][i: i + input_window].values))

x_test = np.array(data)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
y_test = test_set["direction_"][input_window:]
print(x_test.shape, y_test.shape)
# Out:
# (119, 3, 1) (119,)

# %%
# define a function to create the deep neural network model
def create_model():
    np.random.seed(100)
    tf.random.set_seed(100)
    model = Sequential()
    model.add(LSTM(units = 50, return_sequences=True, input_shape=(input_window, 1)))
    model.add(Dropout(0.2))  # Add dropout regularization  
    model.add(LSTM(units = 50))
    model.add(Dropout(0.2))
    model.add(Dense(units=1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', #'rmsprop', 
                  metrics=['accuracy'])
    return model

# %%
model = create_model()
model.summary()
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2023-06-07 18:44:10.227388: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-06-07 18:44:10.227502: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 3, 50)             10400
#
#  dropout (Dropout)           (None, 3, 50)             0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras
early_stop = keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)
r = model.fit(x_train, y_train, epochs=20, batch_size=5, callbacks=early_stop)
# Out:
# Epoch 1/20
# 2023-06-07 18:44:10.595402: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-06-07 18:44:11.399189: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-06-07 18:44:11.703687: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-06-07 18:44:11.763541: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-06-07 18:44:11.909805: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-06-07 18:44:12.078433: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 461/461 [==============================] - 8s 14ms/step - loss: 0.6932 - accuracy: 0.5124
# Epoch 2/20
# 461/461 [==============================] - 6s 13ms/step - loss: 0.6929 - accuracy: 0.5228
# Epoch 3/20
# 461/461 [==============================] - 6s 13ms/step - loss: 0.6920 - accuracy: 0.5232
# Epoch 4/20
# 461/461 [==============================] - 6s 13ms/step - loss: 0.6928 - accuracy: 0.5254
# Epoch 5/20
# 461/461 [==============================] - 6s 13ms/step - loss: 0.6925 - accuracy: 0.5219
# Epoch 6/20
# 461/461 [==============================] - 6s 13ms/step - loss: 0.6924 - accuracy: 0.5232
# Epoch 7/20
# 461/461 [==============================] - 6s 13ms/step - loss: 0.6923 - accuracy: 0.5232

# %%
# predict the direction and map it (1,0)
pred = model.predict(x_test)
# Out:
# 1/4 [======>.......................] - ETA: 1s
# 2023-06-07 18:44:54.524374: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-06-07 18:44:54.613010: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-06-07 18:44:54.645317: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 4/4 [==============================] - 0s 13ms/step

# %%
y_test
# Out:
# 날짜
# 2022-01-14    0
# 2022-01-17    0
# 2022-01-18    0
# 2022-01-19    0
# 2022-01-20    1
#              ..
# 2022-12-28    0
# 2022-12-29    0
# 2023-01-02    0
# 2023-01-03    0
# 2023-01-04    1
# Name: direction_, Length: 240, dtype: int64

# %%
prediction = pred.flatten()
plt.hist(prediction, bins=50)
plt.xlabel("Predicted Value")
plt.ylabel("Frequency")
plt.title("Distribution of Predicted Values")
plt.show()

# %%
# based on prediction calculate the position for strategy
trimmed_test = test[input_window:]
trimmed_test = trimmed_test.loc[:, ['returns', 'direction']]
trimmed_test['position_strategy'] = np.where(pred > np.mean(pred), 1, -1)
trimmed_test.tail(5)
# Out:
#              returns  direction  position_strategy
# 날짜
# 2022-12-28 -0.011875         -1                  1
# 2022-12-29 -0.018082         -1                  1
# 2023-01-02 -0.005931         -1                  1
# 2023-01-03  0.000000          0                  1
# 2023-01-04  0.020855          1                  1

# %%
# calculate daily returns for the strategy
trimmed_test['strategy_return'] = trimmed_test['position_strategy'] * (trimmed_test['returns'])

# %%
# calculate total return and std. deviation of each strategy
print('\nTotal Returns:')
print(trimmed_test[['returns', 'strategy_return']].sum().apply(np.exp))
# Out:
# Total Returns:
# returns            0.974692
# strategy_return    1.103483
# dtype: float64

# %%
# number of trades over time for the strategy
print('Number of trades = ', (trimmed_test['position_strategy'].diff()!=0).sum())
# Out:
# Number of trades =  7

# %%
# plot cumulative returns
fig, ax = plt.subplots(1, 1, sharex=True, figsize = (14,6))
ax.plot(trimmed_test.returns.cumsum().apply(np.exp), label = 'KODEX200 Buy and Hold')
ax.plot(trimmed_test.strategy_return.cumsum().apply(np.exp), label = 'Strategy')
ax.set(title = 'KODEX200 Buy and Hold vs. Strategy', ylabel = 'Cumulative Returns')
ax.grid(True)
ax.legend()
plt.show()

# %% [markdown]
# ### Backtesting using Backtrader

# %%
# backtesting start and end dates
start = test.index[0]
end = test.index[-1]
print(start)
print(end)
# Out:
# 2022-07-11 00:00:00
# 2023-01-04 00:00:00

# %%
# fetch the daily pricing data from yahoo finance
prices = pd.read_csv('./Data/kodex200_data.csv')
prices.head(2)
# Out:
#            날짜       NAV     시가     고가     저가     종가      거래량   괴리율  추적오차율
# 0  2013-01-04  26950.53  27060  27080  26825  26870  5112298 -0.30  -0.01
# 1  2013-01-07  26927.29  26895  26930  26685  26885  4449424 -0.16  -0.03

# %%
prices['날짜'] = pd.to_datetime(prices['날짜'])
prices.set_index('날짜', inplace=True)

# %%
# rename the columns as needed for Backtrader
prices.drop(['NAV', '괴리율', '추적오차율'], inplace=True, axis=1)
prices.rename(columns = {'시가':'open','고가':'high','저가':'low','종가':'close','거래량':'volume',
                         }, inplace=True)

# %%
prices.head(3)
# Out:
#              open   high    low  close   volume
# 날짜
# 2013-01-04  27060  27080  26825  26870  5112298
# 2013-01-07  26895  26930  26685  26885  4449424
# 2013-01-08  26755  26860  26600  26600  3925874

# %%
# add the predicted column to prices dataframe. This will be used as signal for buy or sell
predictions = trimmed_test.strategy_return
predictions = pd.DataFrame(predictions)
predictions.rename(columns = {'strategy_return':'predicted'}, inplace=True)
prices = predictions.join(prices, how='right').dropna()
prices.head(2)
# Out:
#             predicted   open   high    low  close   volume
# 날짜
# 2022-07-14  -0.003575  30590  30935  30500  30710  5896627
# 2022-07-15   0.006006  30900  30935  30335  30895  7255044

# %%
prices[['predicted']].sum().apply(np.exp)
# Out:
# predicted    1.103483
# dtype: float64

# %%
OHLCV = ['open', 'high', 'low', 'close', 'volume']

# %%
# class to define the columns we will provide
class SignalData(PandasData):
    """
    Define pandas DataFrame structure
    """
    cols = OHLCV + ['predicted']

    # create lines
    lines = tuple(cols)

    # define parameters
    params = {c: -1 for c in cols}
    params.update({'datetime': None})
    params = tuple(params.items())

# %% [markdown]
# Strategy:
# 1.	Buy when the predicted value is +1 and sell (only if stock is in possession) when the predicted value is -1.
# 2.	All-in strategy—when creating a buy order, buy as many shares as possible.
# 3.	Short selling is not allowed

# %%
# define backtesting strategy class
class MLStrategy(bt.Strategy):
    params = dict(
    )
    
    def __init__(self):
        # keep track of open, close prices and predicted value in the series
        self.data_predicted = self.datas[0].predicted
        self.data_open = self.datas[0].open
        self.data_close = self.datas[0].close
        
        # keep track of pending orders/buy price/buy commission
        self.order = None
        self.price = None
        self.comm = None

    # logging function
    def log(self, txt):
        '''Logging function'''
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # order already submitted/accepted - no action required
            return

        # report executed order
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f},Commission: {order.executed.comm:.2f}'
                )
                self.price = order.executed.price
                self.comm = order.executed.comm
            else:
                self.log(f'SELL EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f},Commission: {order.executed.comm:.2f}'
                )

        # report failed order
        elif order.status in [order.Canceled, order.Margin, 
                              order.Rejected]:
            self.log('Order Failed')

        # set no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return
        self.log(f'OPERATION RESULT --- Gross: {trade.pnl:.2f}, Net: {trade.pnlcomm:.2f}')

    # We have set cheat_on_open = True.This means that we calculated the signals on day t's close price, 
    # but calculated the number of shares we wanted to buy based on day t+1's open price.
    def next_open(self):
        if not self.position:
            if self.data_predicted > 0:
                # calculate the max number of shares ('all-in')
                size = int(self.broker.getcash() / self.datas[0].open)
                # buy order
#                 self.log(f'BUY CREATED --- Size: {size}, Cash: {self.broker.getcash():.2f}, Open: {self.data_open[0]}, Close: {self.data_close[0]}')
                self.buy(size=size)
        else:
            if self.data_predicted < 0:
                # sell order
#                 self.log(f'SELL CREATED --- Size: {self.position.size}')
                self.sell(size=self.position.size)

# %%
# instantiate SignalData class
data = SignalData(dataname=prices)

# %%
# instantiate Cerebro, add strategy, data, initial cash, commission and pyfolio for performance analysis
cerebro = bt.Cerebro(stdstats = False, cheat_on_open=True)
cerebro.addstrategy(MLStrategy)
cerebro.adddata(data, name=ticker)
cerebro.broker.setcash(100000.0)
cerebro.broker.setcommission(commission=0.001)
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

# %%
# run the backtest
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
start_cash = cerebro.broker.getvalue()
backtest_result = cerebro.run()
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
final_cash = cerebro.broker.getvalue()
# Out:
# Starting Portfolio Value: 100000.00
# 2022-07-15, BUY EXECUTED --- Price: 30900.00, Cost: 92700.00,Commission: 92.70
# 2022-07-20, SELL EXECUTED --- Price: 31985.00, Cost: 92700.00,Commission: 95.95
# 2022-07-20, OPERATION RESULT --- Gross: 3255.00, Net: 3066.34
# 2022-07-22, BUY EXECUTED --- Price: 31985.00, Cost: 95955.00,Commission: 95.95
# 2022-07-25, SELL EXECUTED --- Price: 31750.00, Cost: 95955.00,Commission: 95.25
# 2022-07-25, OPERATION RESULT --- Gross: -705.00, Net: -896.20
# 2022-08-01, BUY EXECUTED --- Price: 32305.00, Cost: 96915.00,Commission: 96.92
# 2022-08-03, SELL EXECUTED --- Price: 32210.00, Cost: 96915.00,Commission: 96.63
# 2022-08-03, OPERATION RESULT --- Gross: -285.00, Net: -478.55
# 2022-08-08, BUY EXECUTED --- Price: 32575.00, Cost: 97725.00,Commission: 97.73
# 2022-08-09, SELL EXECUTED --- Price: 32750.00, Cost: 97725.00,Commission: 98.25
# 2022-08-09, OPERATION RESULT --- Gross: 525.00, Net: 329.02
# 2022-08-10, BUY EXECUTED --- Price: 32670.00, Cost: 98010.00,Commission: 98.01
# 2022-08-11, SELL EXECUTED --- Price: 32830.00, Cost: 98010.00,Commission: 98.49
# 2022-08-11, OPERATION RESULT --- Gross: 480.00, Net: 283.50
# 2022-08-17, BUY EXECUTED --- Price: 33270.00, Cost: 99810.00,Commission: 99.81
# 2022-08-24, SELL EXECUTED --- Price: 32000.00, Cost: 99810.00,Commission: 96.00
# 2022-08-24, OPERATION RESULT --- Gross: -3810.00, Net: -4005.81
# 2022-08-29, BUY EXECUTED --- Price: 31645.00, Cost: 94935.00,Commission: 94.94
# 2022-08-30, SELL EXECUTED --- Price: 31790.00, Cost: 94935.00,Commission: 95.37
# 2022-08-30, OPERATION RESULT --- Gross: 435.00, Net: 244.69
# 2022-09-01, BUY EXECUTED --- Price: 31820.00, Cost: 95460.00,Commission: 95.46
# 2022-09-08, SELL EXECUTED --- Price: 31085.00, Cost: 95460.00,Commission: 93.25
# 2022-09-08, OPERATION RESULT --- Gross: -2205.00, Net: -2393.72
# 2022-09-14, BUY EXECUTED --- Price: 30990.00, Cost: 92970.00,Commission: 92.97
# 2022-09-21, SELL EXECUTED --- Price: 30535.00, Cost: 92970.00,Commission: 91.61
# 2022-09-21, OPERATION RESULT --- Gross: -1365.00, Net: -1549.58
# 2022-09-27, BUY EXECUTED --- Price: 29075.00, Cost: 87225.00,Commission: 87.23
# 2022-09-28, SELL EXECUTED --- Price: 28770.00, Cost: 87225.00,Commission: 86.31
# 2022-09-28, OPERATION RESULT --- Gross: -915.00, Net: -1088.54
# 2022-09-29, BUY EXECUTED --- Price: 28740.00, Cost: 86220.00,Commission: 86.22
# 2022-09-30, SELL EXECUTED --- Price: 28290.00, Cost: 86220.00,Commission: 84.87
# 2022-09-30, OPERATION RESULT --- Gross: -1350.00, Net: -1521.09
# 2022-10-04, BUY EXECUTED --- Price: 28685.00, Cost: 86055.00,Commission: 86.06
# 2022-10-07, SELL EXECUTED --- Price: 28970.00, Cost: 86055.00,Commission: 86.91
# 2022-10-07, OPERATION RESULT --- Gross: 855.00, Net: 682.03
# 2022-10-12, BUY EXECUTED --- Price: 28525.00, Cost: 85575.00,Commission: 85.58
# 2022-10-13, SELL EXECUTED --- Price: 28720.00, Cost: 85575.00,Commission: 86.16
# 2022-10-13, OPERATION RESULT --- Gross: 585.00, Net: 413.26
# 2022-10-14, BUY EXECUTED --- Price: 28780.00, Cost: 86340.00,Commission: 86.34
# 2022-10-19, SELL EXECUTED --- Price: 29470.00, Cost: 86340.00,Commission: 88.41
# 2022-10-19, OPERATION RESULT --- Gross: 2070.00, Net: 1895.25
# 2022-10-21, BUY EXECUTED --- Price: 28840.00, Cost: 86520.00,Commission: 86.52
# 2022-10-28, SELL EXECUTED --- Price: 29690.00, Cost: 86520.00,Commission: 89.07
# 2022-10-28, OPERATION RESULT --- Gross: 2550.00, Net: 2374.41
# 2022-10-31, BUY EXECUTED --- Price: 29845.00, Cost: 89535.00,Commission: 89.53
# 2022-11-02, SELL EXECUTED --- Price: 30270.00, Cost: 89535.00,Commission: 90.81
# 2022-11-02, OPERATION RESULT --- Gross: 1275.00, Net: 1094.65
# 2022-11-04, BUY EXECUTED --- Price: 30065.00, Cost: 90195.00,Commission: 90.20
# 2022-11-11, SELL EXECUTED --- Price: 32140.00, Cost: 90195.00,Commission: 96.42
# 2022-11-11, OPERATION RESULT --- Gross: 6225.00, Net: 6038.39
# 2022-11-14, BUY EXECUTED --- Price: 32435.00, Cost: 97305.00,Commission: 97.31
# 2022-11-15, SELL EXECUTED --- Price: 32285.00, Cost: 97305.00,Commission: 96.86
# 2022-11-15, OPERATION RESULT --- Gross: -450.00, Net: -644.16
# 2022-11-16, BUY EXECUTED --- Price: 32345.00, Cost: 97035.00,Commission: 97.03
# 2022-11-23, SELL EXECUTED --- Price: 31480.00, Cost: 97035.00,Commission: 94.44
# 2022-11-23, OPERATION RESULT --- Gross: -2595.00, Net: -2786.47
# 2022-11-25, BUY EXECUTED --- Price: 31780.00, Cost: 95340.00,Commission: 95.34
# 2022-11-29, SELL EXECUTED --- Price: 31230.00, Cost: 95340.00,Commission: 93.69
# 2022-11-29, OPERATION RESULT --- Gross: -1650.00, Net: -1839.03
# 2022-12-02, BUY EXECUTED --- Price: 32150.00, Cost: 96450.00,Commission: 96.45
# 2022-12-12, SELL EXECUTED --- Price: 31010.00, Cost: 96450.00,Commission: 93.03
# 2022-12-12, OPERATION RESULT --- Gross: -3420.00, Net: -3609.48
# 2022-12-13, BUY EXECUTED --- Price: 31200.00, Cost: 93600.00,Commission: 93.60
# 2022-12-14, SELL EXECUTED --- Price: 31125.00, Cost: 93600.00,Commission: 93.38
# 2022-12-14, OPERATION RESULT --- Gross: -225.00, Net: -411.98
# 2022-12-15, BUY EXECUTED --- Price: 31170.00, Cost: 93510.00,Commission: 93.51
# 2022-12-20, SELL EXECUTED --- Price: 30585.00, Cost: 93510.00,Commission: 91.75
# 2022-12-20, OPERATION RESULT --- Gross: -1755.00, Net: -1940.26
# 2022-12-22, BUY EXECUTED --- Price: 30510.00, Cost: 91530.00,Commission: 91.53
# 2022-12-23, SELL EXECUTED --- Price: 30420.00, Cost: 91530.00,Commission: 91.26
# 2022-12-23, OPERATION RESULT --- Gross: -270.00, Net: -452.79
# 2022-12-26, BUY EXECUTED --- Price: 30205.00, Cost: 90615.00,Commission: 90.61
# 2022-12-28, SELL EXECUTED --- Price: 30355.00, Cost: 90615.00,Commission: 91.06
# 2022-12-28, OPERATION RESULT --- Gross: 450.00, Net: 268.32
# 2023-01-04, BUY EXECUTED --- Price: 29255.00, Cost: 87765.00,Commission: 87.77
# Final Portfolio Value: 95339.47

# %%
final_return = (final_cash-start_cash) / start_cash
print(final_return)
# Out:
# -0.04660530000000028

# %%
# Extract inputs for pyfolio
strat = backtest_result[0]
pyfoliozer = strat.analyzers.getbyname('pyfolio')
returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
returns.name = 'Strategy'
returns.head(2)
# Out:
# index
# 2022-07-14 00:00:00+00:00    0.000000
# 2022-07-15 00:00:00+00:00   -0.001077
# Name: Strategy, dtype: float64

# %%
# get benchmark returns
benchmark_rets= stock['returns']
#benchmark_rets.index = benchmark_rets.index.tz_localize('UTC') 
benchmark_rets = benchmark_rets.filter(returns.index)
benchmark_rets.name = 'KODEX200'
benchmark_rets.head()
# Out:
# Series([], Name: KODEX200, dtype: float64)

# %%
# get performance statistics for strategy
#pf.show_perf_stats(returns)

# %%
# plot performance for strategy vs benchmark
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 9),constrained_layout=True)

#pf.plot_drawdown_periods(returns=returns, ax=axes[0])
#ax[0].grid(True)
pf.plot_rolling_returns(returns=returns,
                        factor_returns=benchmark_rets,
                        title='Strategy vs KODEX200 Buy&Hold')
#axes[1].grid(True)
#pf.plot_drawdown_underwater(returns=returns, ax=axes[2])
#axes[2].grid(True)
#pf.plot_rolling_sharpe(returns=returns, ax=axes[3])
#axes[3].grid(True)
# fig.suptitle('XXX', fontsize=16, y=0.990)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 6
#       2 fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16, 9),constrained_layout=True)
#       4 #pf.plot_drawdown_periods(returns=returns, ax=axes[0])
#       5 #ax[0].grid(True)
# ----> 6 pf.plot_rolling_returns(returns=returns,
#       7                         factor_returns=benchmark_rets,
#       8                         title='Strategy vs KODEX200 Buy&Hold')
#       9 #axes[1].grid(True)
#      10 #pf.plot_drawdown_underwater(returns=returns, ax=axes[2])
#      11 #axes[2].grid(True)
#      12 #pf.plot_rolling_sharpe(returns=returns, ax=axes[3])
#      13 #axes[3].grid(True)
#      14 # fig.suptitle('XXX', fontsize=16, y=0.990)
#      16 plt.grid(True)
#
# File ~/miniforge3/envs/main/lib/python3.8/site-packages/pyfolio/plotting.py:794, in plot_rolling_returns(returns, factor_returns, live_start_date, logy, cone_std, legend_loc, volatility_match, cone_function, ax, **kwargs)
#     790 ax.yaxis.set_major_formatter(FuncFormatter(y_axis_formatter))
#     792 if factor_returns is not None:
#     793     cum_factor_returns = ep.cum_returns(
# --> 794         factor_returns[cum_rets.index], 1.0)
#     795     cum_factor_returns.plot(lw=2, color='gray',
#     796                             label=factor_returns.name, alpha=0.60,
#     797                             ax=ax, **kwargs)
#     799 if live_start_date is not None:
#
# File ~/miniforge3/envs/main/lib/python3.8/site-packages/pandas/core/series.py:1033, in Series.__getitem__(self, key)
#    1030     key = np.asarray(key, dtype=bool)
#    1031     return self._get_values(key)
# -> 1033 return self._get_with(key)
#
# File ~/miniforge3/envs/main/lib/python3.8/site-packages/pandas/core/series.py:1073, in Series._get_with(self, key)
#    1070         return self.iloc[key]
#    1072 # handle the dup indexing case GH#4246
# -> 1073 return self.loc[key]
#
# File ~/miniforge3/envs/main/lib/python3.8/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniforge3/envs/main/lib/python3.8/site-packages/pandas/core/indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# File ~/miniforge3/envs/main/lib/python3.8/site-packages/pandas/core/indexing.py:1272, in _LocIndexer._getitem_iterable(self, key, axis)
#    1269 self._validate_key(key, axis)
#    1271 # A collection of keys
# -> 1272 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1273 return self.obj._reindex_with_indexers(
#    1274     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1275 )
#
# File ~/miniforge3/envs/main/lib/python3.8/site-packages/pandas/core/indexing.py:1462, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1459 ax = self.obj._get_axis(axis)
#    1460 axis_name = self.obj._get_axis_name(axis)
# -> 1462 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1464 return keyarr, indexer
#
# File ~/miniforge3/envs/main/lib/python3.8/site-packages/pandas/core/indexes/base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File ~/miniforge3/envs/main/lib/python3.8/site-packages/pandas/core/indexes/base.py:5935, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5933     if use_interval_msg:
#    5934         key = list(key)
# -> 5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [DatetimeIndex(['2022-07-14 00:00:00+00:00', '2022-07-15 00:00:00+00:00',\n               '2022-07-18 00:00:00+00:00', '2022-07-19 00:00:00+00:00',\n               '2022-07-20 00:00:00+00:00', '2022-07-21 00:00:00+00:00',\n               '2022-07-22 00:00:00+00:00', '2022-07-25 00:00:00+00:00',\n               '2022-07-26 00:00:00+00:00', '2022-07-27 00:00:00+00:00',\n               ...\n               '2022-12-21 00:00:00+00:00', '2022-12-22 00:00:00+00:00',\n               '2022-12-23 00:00:00+00:00', '2022-12-26 00:00:00+00:00',\n               '2022-12-27 00:00:00+00:00', '2022-12-28 00:00:00+00:00',\n               '2022-12-29 00:00:00+00:00', '2023-01-02 00:00:00+00:00',\n               '2023-01-03 00:00:00+00:00', '2023-01-04 00:00:00+00:00'],\n              dtype='datetime64[ns, UTC]', name='index', length=119, freq=None)] are in the [index]"

# %%
# plot performance for strategy vs benchmark
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(16, 9),constrained_layout=True)
# pf.plot_rolling_beta(returns=returns, factor_returns=benchmark_rets, ax=axes[0])
# axes[0].grid(True)

# #pf.plot_rolling_volatility(returns=returns, factor_returns=benchmark_rets,ax=axes[1])
# axes[1].grid(True)

#pf.plot_annual_returns(returns=returns, ax=axes[0])
#axes[0].grid(True)

pf.plot_monthly_returns_heatmap(returns=returns)
# fig.suptitle('XXX', fontsize=16, y=1.0)


plt.tight_layout()
